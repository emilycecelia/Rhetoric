# %%
# %matplotlib inline
import rhetoric
import os
import pandas as pd

# %%
speech_meta = ['speaker','name']
speech_metrics = []
for fn in os.listdir('speeches/CallToWar/'):
    if fn.endswith('.txt'):
        speaker,name=fn.rstrip('.txt').split('-')
        print(speaker,name)
        fp = 'speeches/CallToWar/' + fn
        text = open(fp).read().lower()
        metrics = rhetoric.evaluate_speech(text)
        metrics['name'] = name
        metrics['speaker'] = speaker
        speech_metrics.append(metrics)
metrics_df = pd.DataFrame(speech_metrics)

groups = {'Rhetorical Devices':rhetoric.devices_cols, 'Token Counts':rhetoric.counts_cols, 
          'Pronoun Dist':rhetoric.pronoun_cols, 'Diversity': rhetoric.other_dist}
war_clusters = rhetoric.cluster_speeches(metrics_df, rhetoric.devices_cols+rhetoric.counts_cols+
                                         rhetoric.pronoun_cols + rhetoric.other_dist, ['speaker','name'], 3, groups)

# %%
war_clusters_2 = rhetoric.cluster_speeches(metrics_df, rhetoric.devices_cols+rhetoric.counts_cols+
                                           rhetoric.pronoun_cols + rhetoric.other_dist, ['speaker','name'], 2, groups)

# %%
inaugural_speech_metrics = []
for fn in os.listdir('speeches/PresidentialNom/'):
    if fn.endswith('.txt'):
        party,speaker,year=fn.rstrip('.txt').split('-')
        print(party,speaker,year)
        fp = 'speeches/PresidentialNom/' + fn
        text = open(fp).read().lower()
        metrics = rhetoric.evaluate_speech(text)
        metrics['party'] = party
        metrics['speaker'] = speaker
        metrics['year'] = year
        inaugural_speech_metrics.append(metrics)
inaugural_metrics_df = pd.DataFrame(inaugural_speech_metrics)
# Out:
# Dem Carter 1976
# Dem Carter 1980
# Dem Clinton 1992
# Dem Clinton 1996
# Dem Dukakis 1988
# Dem Gore 2000
# Dem Humphrey 1968
# Dem Johnson 1964
# Dem Kennedy 1960
# Dem Kerry 2004
# Dem McGovern 1972
# Dem Mondale 1984
# Dem Obama 2008
# Dem Obama 2012
# GOP Bush 1988
# GOP Bush 1992
# GOP Dole 1996
# GOP Ford 1976
# GOP Goldwater 1964
# GOP McCain 2008
# GOP Nixon 1960
# GOP Nixon 1968
# GOP Nixon 1972
# GOP Reagan 1980
# GOP Reagan 1984
# GOP Romney 2012
# GOP WBush 2000
# GOP WBush 2004

# %%
inaugural_metrics_df.head()
# Out:
#    alliteration_count  conclusion_count  conditional_count  epitrophe_count  \
# 0            0.066092          0.000000           0.006466         0.038793
# 1            0.075238          0.000827           0.004547         0.029351
# 2            0.089122          0.000000           0.010055         0.031079
# 3            0.077662          0.000282           0.007625         0.024569
# 4            0.073112          0.000604           0.007855         0.028399
#
#    example_count  opposition_count  result_count  rhetoric_count  \
# 0       0.001437          0.012931      0.000000        0.000000
# 1       0.003307          0.014882      0.000827        0.003721
# 2       0.002742          0.021938      0.000000        0.002742
# 3       0.001694          0.011296      0.000282        0.003954
# 4       0.003021          0.010272      0.000604        0.000000
#
#    sequence_count  similarity_count  ...         us        we       you  \
# 0        0.019397          0.005029  ...   0.005258  0.020414  0.004021
# 1        0.024804          0.003721  ...   0.002103  0.017970  0.004588
# 2        0.021938          0.005484  ...   0.004906  0.014914  0.010204
# 3        0.023722          0.003954  ...   0.002788  0.023695  0.007476
# 4        0.022961          0.004230  ...   0.003291  0.021942  0.007131
#
#        your  yours  yourself  yourselves  party  speaker  year
# 0  0.002165    0.0  0.000000         0.0    Dem   Carter  1976
# 1  0.002103    0.0  0.000000         0.0    Dem   Carter  1980
# 2  0.003532    0.0  0.000196         0.0    Dem  Clinton  1992
# 3  0.001647    0.0  0.000000         0.0    Dem  Clinton  1996
# 4  0.000549    0.0  0.000000         0.0    Dem  Dukakis  1988
#
# [5 rows x 48 columns]

# %%
inaugural_clusters = rhetoric.cluster_speeches(inaugural_metrics_df, rhetoric.devices_cols+rhetoric.counts_cols+
                                         rhetoric.pronoun_cols + rhetoric.other_dist, ['party','speaker', 'year'], 2, groups)

# %%
inaugural_clusters[0].groupby(['party','cluster']).size().to_frame()
# Out:
#                 0
# party cluster
# Dem   0        12
#       1         2
# GOP   0        11
#       1         3

# %%
inaugural_clusters[0][inaugural_clusters[0].cluster == 1]
# Out:
#     cluster party    speaker  year
# 4         1   Dem    Dukakis  1988
# 10        1   Dem   McGovern  1972
# 18        1   GOP  Goldwater  1964
# 20        1   GOP      Nixon  1960
# 23        1   GOP     Reagan  1980

# %%
all_speakers = inaugural_metrics_df['speaker'].tolist()
def second_term(row):
    speaker = row['speaker']
    if all_speakers.count(speaker) == 2:
        this_year = row['year']
        reelect_year = inaugural_metrics_df[inaugural_metrics_df.speaker==row['speaker']]['year'].max()
        if this_year == reelect_year:
            return True
    return False

inaugural_metrics_df['reelection'] = inaugural_metrics_df.apply(second_term, axis=1)

# %%
inaugural_clusters = rhetoric.cluster_speeches(inaugural_metrics_df, rhetoric.devices_cols+rhetoric.counts_cols+
                                         rhetoric.pronoun_cols + rhetoric.other_dist, ['party','speaker', 'year', 'reelection'], 2, groups)

# %%
inaugural_clusters[0].groupby(['reelection','cluster']).size().to_frame()
# Out:
#                      0
# reelection cluster
# False      0        17
#            1         5
# True       0         6
